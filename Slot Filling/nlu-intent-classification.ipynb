# %%
import json
import os
import pandas as pd
import numpy as np

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text
import seaborn as sns
from pylab import rcParams
import random

import matplotlib.pyplot as plt
tf.get_logger().setLevel('ERROR')

sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
rcParams['figure.figsize'] = 12, 8
import warnings
warnings.filterwarnings("ignore")

# %%
# Detect hardware, return appropriate distribution strategy (you can see that it is pretty easy to set up).
try:
    # TPU detection. No parameters necessary if TPU_NAME environment variable is set (always set in Kaggle)
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
    print('Running on TPU ', tpu.master())
except ValueError:
    # Default distribution strategy in Tensorflow. Works on CPU and single GPU.
    strategy = tf.distribute.get_strategy()

print('Number of replicas:', strategy.num_replicas_in_sync)
# Out:
# Number of replicas: 1

# %%
# Read data from JSON file
with open('/kaggle/input/hackathon-online-nlu-intent-classification/train.json') as json_file: 
    data_dict = json.load(json_file) 
    
with open('/kaggle/input/hackathon-online-nlu-intent-classification/valid.json') as json_file: 
    vdata_dict = json.load(json_file)

# %%
data_dict
# Out:
# [{'utterance': 'will it be rainy in tenino',
#   'slots': 'O O O B-condition_description O B-city',
#   'intent': 'GetWeather'},
#  {'utterance': 'add steve albini album to my psychedelic rock playlist',
#   'slots': 'O B-artist I-artist B-music_item O B-playlist_owner B-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'book a table for 3 at one of the restaurants in washington  d c  in riverview',
#   'slots': 'O O O O B-party_size_number O O O O B-restaurant_name I-restaurant_name I-restaurant_name I-restaurant_name I-restaurant_name O B-city',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'what s the weather forecast for belknap',
#   'slots': 'O O O O O O B-city',
#   'intent': 'GetWeather'},
#  {'utterance': 'play fereydoun farrokhzad best track',
#   'slots': 'O B-artist I-artist B-sort B-music_item',
#   'intent': 'PlayMusic'},
#  {'utterance': 'put kan mikami on pre-party r&b jams',
#   'slots': 'O B-artist I-artist O B-playlist I-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'look for the chu chu and the philly flash picture',
#   'slots': 'O O O B-object_name I-object_name I-object_name I-object_name I-object_name I-object_name B-object_type',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'play the god that failed on vimeo',
#   'slots': 'O B-track I-track I-track I-track O B-service',
#   'intent': 'PlayMusic'},
#  {'utterance': 'play a soundtrack by mike hindert on spotify',
#   'slots': 'O O B-music_item O B-artist I-artist O B-service',
#   'intent': 'PlayMusic'},
#  {'utterance': 'want to watch the tv show treeful of starling',
#   'slots': 'O O O O B-object_type I-object_type B-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'how much hotter will it be 40 weeks from now in blue island  north dakota',
#   'slots': 'O O B-condition_temperature O O O B-timeRange I-timeRange I-timeRange I-timeRange O B-city I-city B-state I-state',
#   'intent': 'GetWeather'},
#  {'utterance': 'put a l lloyd on gaming anthems',
#   'slots': 'O B-artist I-artist I-artist O B-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'find trailer of jazz impressions of the u s a',
#   'slots': 'O B-object_type O B-object_name I-object_name I-object_name I-object_name I-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'when is percy jackson playing at the movie theatre',
#   'slots': 'O O B-movie_name I-movie_name O O O B-object_location_type I-object_location_type',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'let me get reservations for a party of three at a bar with a pool',
#   'slots': 'O O O O O O O O B-party_size_number O O B-restaurant_type O O B-facility',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'rate the country blues 3 out of 6 stars',
#   'slots': 'O B-object_name I-object_name I-object_name B-rating_value O O B-best_rating B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'i want to hear jimmy james from the thirties  play a song on groove shark',
#   'slots': 'O O O O B-artist I-artist O O B-year O O B-music_item O B-service I-service',
#   'intent': 'PlayMusic'},
#  {'utterance': 'put sungmin into my summer playlist',
#   'slots': 'O B-artist O B-playlist_owner B-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'play a twenties song',
#   'slots': 'O O B-year B-music_item',
#   'intent': 'PlayMusic'},
#  {'utterance': 'find a television show called milagros: girl from away',
#   'slots': 'O O B-object_type I-object_type O B-object_name I-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'find the flying scotsman',
#   'slots': 'O B-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'what is the forecast in nicodemus and nearby',
#   'slots': 'O O O O O B-city O B-spatial_relation',
#   'intent': 'GetWeather'},
#  {'utterance': 'find the novel peace arch news',
#   'slots': 'O O B-object_type B-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'please make me reservations somewhere for eight people in foley  nv',
#   'slots': 'O O O O O O B-party_size_number O O B-city B-state',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'what is the weather forecast for new mexico',
#   'slots': 'O O O O O O B-state I-state',
#   'intent': 'GetWeather'},
#  {'utterance': 'find the movie schedule for 12:53 am',
#   'slots': 'O O B-object_type I-object_type O B-timeRange I-timeRange',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'add tune to african heat',
#   'slots': 'O B-music_item O B-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'find a picture called battlefield network',
#   'slots': 'O O B-object_type O B-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'is it going to be hot in lexington-fayette',
#   'slots': 'O O O O O B-condition_temperature O B-city',
#   'intent': 'GetWeather'},
#  {'utterance': 'add time flies 1994-2009 to the jazzy romance playlist',
#   'slots': 'O B-entity_name I-entity_name I-entity_name O O B-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'can you find the tv show faithless street',
#   'slots': 'O O O O B-object_type I-object_type B-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'show chocolate rain creativity',
#   'slots': 'B-object_type B-object_name I-object_name O',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'can you search a song for mama book for me',
#   'slots': 'O O O B-object_name I-object_name I-object_name I-object_name B-object_type O O',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'is it forecast to be windy here in seven seconds',
#   'slots': 'O O O O O B-condition_description B-current_location B-timeRange I-timeRange I-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'i would give the all that: fresh out the box saga a rating of 2 points',
#   'slots': 'O O O O B-object_name I-object_name I-object_name I-object_name I-object_name I-object_name B-object_part_of_series_type O O O B-rating_value B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'show the schedule of movie unborn but forgotten',
#   'slots': 'O O B-object_type O O B-movie_name I-movie_name I-movie_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'add rob tyner to betsy s we everywhere',
#   'slots': 'O B-artist I-artist O B-playlist_owner I-playlist_owner B-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'add this artist to lo más dance playlist',
#   'slots': 'O O B-music_item O B-playlist I-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'will there be a lot of wind in west fargo gu',
#   'slots': 'O O O O O O B-condition_description O B-city I-city B-state',
#   'intent': 'GetWeather'},
#  {'utterance': 'will there be a blizzard in saudi arabia around 2 o clock',
#   'slots': 'O O O O B-condition_description O B-country I-country B-spatial_relation B-timeRange I-timeRange I-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'i need a party of two reservation faraway from atlantic av-barclays ctr at a spa for fast food',
#   'slots': 'O O O O O B-party_size_number O B-spatial_relation O B-poi I-poi I-poi O O B-facility O B-restaurant_type I-restaurant_type',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'restaurant in zimbabwe that is brasserie and has parking',
#   'slots': 'B-restaurant_type O B-country O O B-restaurant_type O O B-facility',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'show the ancient art of war picture',
#   'slots': 'O B-object_name I-object_name I-object_name I-object_name I-object_name B-object_type',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'please find me the video game titled 20 hours in america',
#   'slots': 'O O O O B-object_type I-object_type O B-object_name I-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'find the dead matter at speakeasy theaters',
#   'slots': 'O B-movie_name I-movie_name I-movie_name O B-location_name I-location_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'what is the forecast on 12/9/2039 at florida caverns state park',
#   'slots': 'O O O O O B-timeRange O B-geographic_poi I-geographic_poi I-geographic_poi I-geographic_poi',
#   'intent': 'GetWeather'},
#  {'utterance': 'book a restaurant this year for party of 2',
#   'slots': 'O O B-restaurant_type B-timeRange I-timeRange O O O B-party_size_number',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'play a chant from the fifties',
#   'slots': 'O O B-music_item O O B-year',
#   'intent': 'PlayMusic'},
#  {'utterance': 'give the snows of kilimanjaro 3 stars',
#   'slots': 'O B-object_name I-object_name I-object_name I-object_name B-rating_value B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'rate personal demons 0 out of 6 points',
#   'slots': 'O B-object_name I-object_name B-rating_value O O B-best_rating B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'is it supposed to be chilly in de tonight',
#   'slots': 'O O O O O B-condition_temperature O B-state B-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'add a song by claude vonstroke to the under the surface playlist',
#   'slots': 'O O B-music_item O B-artist I-artist O O B-playlist I-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'find a tv series called cocktail kings',
#   'slots': 'O O B-object_type I-object_type O B-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'tell me the weather forecast for inniswold  réunion',
#   'slots': 'O O O O O O B-city B-country',
#   'intent': 'GetWeather'},
#  {'utterance': 'can you pull up the sanford herald',
#   'slots': 'O O O O B-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'book a table for three at 0 am at a bar with wifi in schuyler lake',
#   'slots': 'O O O O B-party_size_number O B-timeRange I-timeRange O O B-restaurant_type O B-facility O B-city I-city',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'play any song from rebecca hewitt',
#   'slots': 'O O B-music_item O B-artist I-artist',
#   'intent': 'PlayMusic'},
#  {'utterance': 'i want to see the movie schedules for animated movies around here',
#   'slots': 'O O O O O B-object_type I-object_type O B-movie_type I-movie_type B-spatial_relation I-spatial_relation',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'add d flame to the dcode2016 playlist',
#   'slots': 'O B-artist I-artist O O B-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'play music from 2010 by jason donovan',
#   'slots': 'O O O B-year O B-artist I-artist',
#   'intent': 'PlayMusic'},
#  {'utterance': 'please find me the classified book',
#   'slots': 'O O O O B-object_name B-object_type',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'how will the weather be in new mexico around 00:09:07 am',
#   'slots': 'O O O O O O B-state I-state O B-timeRange I-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'rate this series 0 of 6 stars',
#   'slots': 'O B-object_select B-object_part_of_series_type B-rating_value O B-best_rating B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'give 5 of 6 stars to expressive processing',
#   'slots': 'O B-rating_value O B-best_rating B-rating_unit O B-object_name I-object_name',
#   'intent': 'RateBook'},
#  {'utterance': 'can i get the movie times for fox theatres',
#   'slots': 'O O O O B-object_type I-object_type O B-location_name I-location_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'i would rate the codebreakers a rating of 6 and a value of 2',
#   'slots': 'O O O B-object_name I-object_name O O O B-best_rating O O O O B-rating_value',
#   'intent': 'RateBook'},
#  {'utterance': 'add this tune to my this is luis fonsi playlist',
#   'slots': 'O O B-music_item O B-playlist_owner B-playlist I-playlist I-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'find resurrection of evil',
#   'slots': 'O B-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'is it warm in fernley',
#   'slots': 'O O B-condition_temperature O B-city',
#   'intent': 'GetWeather'},
#  {'utterance': 'is it overcast in south carolina',
#   'slots': 'O O B-condition_description O B-state I-state',
#   'intent': 'GetWeather'},
#  {'utterance': 'rate the current novel 1 out of 6 points',
#   'slots': 'O O B-object_select B-object_type B-rating_value O O B-best_rating B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'rate getting it wrong from the beginning a value of 4',
#   'slots': 'O B-object_name I-object_name I-object_name I-object_name I-object_name I-object_name O O O B-rating_value',
#   'intent': 'RateBook'},
#  {'utterance': 'play something from 1985 by billy werner',
#   'slots': 'O O O B-year O B-artist I-artist',
#   'intent': 'PlayMusic'},
#  {'utterance': 'where is white bim black ear',
#   'slots': 'O O B-movie_name I-movie_name I-movie_name I-movie_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'rate this novel 5 out of 6 stars',
#   'slots': 'O B-object_select B-object_type B-rating_value O O B-best_rating B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'find me the book with the title of the rainwater lp',
#   'slots': 'O O O B-object_type O O O O B-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'what is the weather like in antonito',
#   'slots': 'O O O O O O B-city',
#   'intent': 'GetWeather'},
#  {'utterance': 'please play a song off the curtis lee album rough diamonds',
#   'slots': 'O O O B-music_item O O B-artist I-artist B-music_item B-album I-album',
#   'intent': 'PlayMusic'},
#  {'utterance': 'play chant music by pappu venugopala rao on slacker',
#   'slots': 'O B-music_item O O B-artist I-artist I-artist O B-service',
#   'intent': 'PlayMusic'},
#  {'utterance': 'give 1 star to this album',
#   'slots': 'O B-rating_value O O B-object_select B-object_type',
#   'intent': 'RateBook'},
#  {'utterance': 'rate the road to reality: a complete guide to the laws of the universe two points',
#   'slots': 'O B-object_name I-object_name I-object_name I-object_name I-object_name I-object_name I-object_name I-object_name I-object_name I-object_name I-object_name I-object_name I-object_name B-rating_value B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'play me a song by saki nakajima',
#   'slots': 'O O O B-music_item O B-artist I-artist',
#   'intent': 'PlayMusic'},
#  {'utterance': 'find me a showing of the vanquished that starts nine hours and 1 second from now',
#   'slots': 'O O O O O B-movie_name I-movie_name O O B-timeRange I-timeRange I-timeRange I-timeRange I-timeRange I-timeRange I-timeRange',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'what s the closest movie theatre showing harbour beat',
#   'slots': 'O O O B-spatial_relation B-object_location_type I-object_location_type O B-movie_name I-movie_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'i would give this current textbook a rating of 1 points and a best rating of 6',
#   'slots': 'O O O O B-object_select B-object_type O O O B-rating_value B-rating_unit O O O O O B-best_rating',
#   'intent': 'RateBook'},
#  {'utterance': 'play morning song',
#   'slots': 'O B-album I-album',
#   'intent': 'PlayMusic'},
#  {'utterance': 'will it get cold in nevada seven weeks and a half from now',
#   'slots': 'O O O B-condition_temperature O B-state B-timeRange I-timeRange I-timeRange I-timeRange I-timeRange I-timeRange I-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'book a restaurant for seven',
#   'slots': 'O O B-restaurant_type O B-party_size_number',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'what s the weather forecast ten years from now in mount victory  macao',
#   'slots': 'O O O O O B-timeRange I-timeRange I-timeRange I-timeRange O B-city I-city B-country',
#   'intent': 'GetWeather'},
#  {'utterance': 'find films at alamo drafthouse cinema',
#   'slots': 'O B-movie_type O B-location_name I-location_name I-location_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'play music from the artist sean yseult and sort it through top-50',
#   'slots': 'O O O O O B-artist I-artist O O O O B-sort',
#   'intent': 'PlayMusic'},
#  {'utterance': 'i want to give panther in the basement four points',
#   'slots': 'O O O O B-object_name I-object_name I-object_name I-object_name B-rating_value B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'find a painting called songs from tsongas',
#   'slots': 'O O B-object_type O B-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'add album to ultra metal',
#   'slots': 'O B-music_item O B-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'need a table at colony in sri lanka next year',
#   'slots': 'O O O O B-restaurant_name O B-country I-country B-timeRange I-timeRange',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'i d like to see movie times at santikos theatres',
#   'slots': 'O O O O O B-object_type I-object_type O B-location_name I-location_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'play kurt cobain ballad tunes',
#   'slots': 'O B-artist I-artist B-music_item O',
#   'intent': 'PlayMusic'},
#  {'utterance': 'rate my current book five points out of 6',
#   'slots': 'O O B-object_select B-object_type B-rating_value B-rating_unit O O B-best_rating',
#   'intent': 'RateBook'},
#  {'utterance': 'can you make reservations for two people somewhere distant from sutphin blvd',
#   'slots': 'O O O O O B-party_size_number O O B-spatial_relation O B-poi I-poi',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'give two out of 6 points to current textbook',
#   'slots': 'O B-rating_value O O B-best_rating B-rating_unit O B-object_select B-object_type',
#   'intent': 'RateBook'},
#  {'utterance': 'where is the toxic avenger ii playing',
#   'slots': 'O O B-movie_name I-movie_name I-movie_name I-movie_name O',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'i m rating the skystone with three points',
#   'slots': 'O O O B-object_name I-object_name O B-rating_value B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'looking for the photograph the crimson climax',
#   'slots': 'O O O B-object_type O B-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'will it be freezing at 1 am in balko',
#   'slots': 'O O O B-condition_temperature O B-timeRange I-timeRange O B-city',
#   'intent': 'GetWeather'},
#  {'utterance': 'want a table at monty’s hotel  secunderabad  in the state of vermont',
#   'slots': 'O O O O B-restaurant_name I-restaurant_name I-restaurant_name O O O O B-state',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'search for the song banquet for the damned',
#   'slots': 'O O O B-object_type B-object_name I-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'book a reservation for a brasserie serving soupe in tokelau',
#   'slots': 'O O O O O B-restaurant_type O B-served_dish O B-country',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'give this current essay a 3 out of 6',
#   'slots': 'O O B-object_select B-object_type O B-rating_value O O B-best_rating',
#   'intent': 'RateBook'},
#  {'utterance': 'find a movie schedule',
#   'slots': 'O O B-object_type I-object_type',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'forecast for willits christmas island twenty three minutes from now',
#   'slots': 'O O B-city B-country I-country B-timeRange I-timeRange I-timeRange I-timeRange I-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'add a track to the emo forever playlist',
#   'slots': 'O O B-music_item O O B-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'find the show the naked gun',
#   'slots': 'O O B-object_type B-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'i need a reservation for the original house of pies with three people in plandome manor pa',
#   'slots': 'O O O O O B-restaurant_name I-restaurant_name I-restaurant_name I-restaurant_name I-restaurant_name O B-party_size_number O O B-city I-city B-state',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'please book me a table for three at an american gastropub',
#   'slots': 'O O O O O O B-party_size_number O O B-cuisine B-restaurant_type',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'what movie times',
#   'slots': 'O B-object_type I-object_type',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'please search for mary',
#   'slots': 'O O O B-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'play the crowd: a study of the popular mind soundtrack',
#   'slots': 'O B-object_name I-object_name I-object_name I-object_name I-object_name I-object_name I-object_name I-object_name B-object_type',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'where can i listen to the song the imposter',
#   'slots': 'O O O O O O B-object_type B-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'looking for a black ribbon for deborah',
#   'slots': 'O O B-object_name I-object_name I-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'play the video game the genesis machine',
#   'slots': 'O O B-object_type I-object_type B-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'play some 1993 concerto off of slacker',
#   'slots': 'O O B-year B-music_item O O B-service',
#   'intent': 'PlayMusic'},
#  {'utterance': 'rate this current essay 1 out of 6 points',
#   'slots': 'O O B-object_select B-object_type B-rating_value O O B-best_rating B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'add a song to indie hipster',
#   'slots': 'O O B-music_item O B-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'find the movie schedule for 20:45:24',
#   'slots': 'O O B-object_type I-object_type O B-timeRange',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'play music by daddy yankee',
#   'slots': 'O O O B-artist I-artist',
#   'intent': 'PlayMusic'},
#  {'utterance': 'add a track by bt to my independent music monday playlist',
#   'slots': 'O O B-music_item O B-artist O B-playlist_owner B-playlist I-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'book a reservation for seven people at a bar in kentucky',
#   'slots': 'O O O O B-party_size_number O O O B-restaurant_type O B-state',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'add this tune to my weekend playlist',
#   'slots': 'O O B-music_item O B-playlist_owner B-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'book a spot at savoy hotel and grill that is neighboring wisconsin',
#   'slots': 'O O O O B-restaurant_name I-restaurant_name I-restaurant_name I-restaurant_name O O B-spatial_relation B-state',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'book a table for eight people please',
#   'slots': 'O O O O B-party_size_number O O',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'what is the forecast in north carolina for edgemoor',
#   'slots': 'O O O O O B-state I-state O B-city',
#   'intent': 'GetWeather'},
#  {'utterance': 'how will the weather be this month in or',
#   'slots': 'O O O O O B-timeRange I-timeRange O B-state',
#   'intent': 'GetWeather'},
#  {'utterance': 'will it be snowy in pillow indiana',
#   'slots': 'O O O B-condition_description O B-city B-state',
#   'intent': 'GetWeather'},
#  {'utterance': 'play noche de chicas playlist',
#   'slots': 'O B-playlist I-playlist I-playlist O',
#   'intent': 'PlayMusic'},
#  {'utterance': 'play me a ballad by dres on groove shark',
#   'slots': 'O O O B-music_item O B-artist O B-service I-service',
#   'intent': 'PlayMusic'},
#  {'utterance': 'add this artist named trevor mcnevan to the playlist top gaming tracks',
#   'slots': 'O O B-music_item O B-artist I-artist O O O B-playlist I-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'add this jane olivor track to my the sleep machine waterscapes',
#   'slots': 'O O B-artist I-artist B-music_item O B-playlist_owner B-playlist I-playlist I-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'book a table for 8 right now for a restaurant in meadow vale',
#   'slots': 'O O O O B-party_size_number O B-timeRange O O B-restaurant_type O B-city I-city',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'will it get warmer in berkley',
#   'slots': 'O O O B-condition_temperature O B-city',
#   'intent': 'GetWeather'},
#  {'utterance': 'find the movie schedule for amco entertainment 1 minute from now',
#   'slots': 'O O B-object_type I-object_type O B-location_name I-location_name B-timeRange I-timeRange I-timeRange I-timeRange',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'what will it feel like in the current place in july',
#   'slots': 'O O O O O O O B-current_location I-current_location O B-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'i need to book a restaurant in fork mountain  sc for valarie  mari and i',
#   'slots': 'O O O O O B-restaurant_type O B-city I-city B-state O B-party_size_description I-party_size_description I-party_size_description I-party_size_description',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'find the films at century theatres',
#   'slots': 'O O B-movie_type O B-location_name I-location_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'please search the title the twilight saga: breaking dawn part 2',
#   'slots': 'O O O O B-object_name I-object_name I-object_name I-object_name I-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'the workout playlist needs more chris cross',
#   'slots': 'O B-playlist O O O B-artist I-artist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'rate the book magic: history  theory and practice five stars',
#   'slots': 'O O B-object_type B-object_name I-object_name I-object_name I-object_name I-object_name B-rating_value B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'what will the weather be this month in wesley hills',
#   'slots': 'O O O O O B-timeRange I-timeRange O B-city I-city',
#   'intent': 'GetWeather'},
#  {'utterance': 'can you find the novel journal of social work',
#   'slots': 'O O O O B-object_type B-object_name I-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'the next essay gets 2 out of 6 stars',
#   'slots': 'O B-object_select B-object_type O B-rating_value O O B-best_rating B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'book a popular tuscan restaurant for 7 people in west richfield',
#   'slots': 'O O B-sort B-cuisine B-restaurant_type O B-party_size_number O O B-city I-city',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'this chronicle is a zero out of 6',
#   'slots': 'B-object_select B-object_part_of_series_type O O B-rating_value O O B-best_rating',
#   'intent': 'RateBook'},
#  {'utterance': 'rate  body of secrets one stars',
#   'slots': 'O B-object_name I-object_name I-object_name B-rating_value B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'rate the current essay 0',
#   'slots': 'O O B-object_select B-object_type B-rating_value',
#   'intent': 'RateBook'},
#  {'utterance': 'want to find a photograph called the nine maidens',
#   'slots': 'O O O O B-object_type O B-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'play pura vida',
#   'slots': 'O B-playlist I-playlist',
#   'intent': 'PlayMusic'},
#  {'utterance': 'list movies for nearest movie house at brunch time',
#   'slots': 'O B-movie_type O B-spatial_relation B-object_location_type I-object_location_type O B-timeRange O',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'add this song to indie hipster',
#   'slots': 'O O B-music_item O B-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'what will the weather be like in lambertville  india at ten pm',
#   'slots': 'O O O O O O O B-city B-country O B-timeRange I-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'play a chaos of desire from dan snaith',
#   'slots': 'O B-album I-album I-album I-album O B-artist I-artist',
#   'intent': 'PlayMusic'},
#  {'utterance': 'find a movie schedule',
#   'slots': 'O O B-object_type I-object_type',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'add falling stars to my intense studying',
#   'slots': 'O B-entity_name I-entity_name O B-playlist_owner B-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'what is the weather in gipsy-gordon wildland park',
#   'slots': 'O O O O O B-geographic_poi I-geographic_poi I-geographic_poi',
#   'intent': 'GetWeather'},
#  {'utterance': 'add jenifer to rock the 2000 s',
#   'slots': 'O B-artist O B-playlist I-playlist I-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'tell me what movies are showing at seven am at the closest movie house',
#   'slots': 'O O O B-movie_type O O O B-timeRange I-timeRange O O B-spatial_relation B-object_location_type I-object_location_type',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'i would like you to add now the hits of winter 2008 onto my ntc studio sounds playlist',
#   'slots': 'O O O O O O B-entity_name I-entity_name I-entity_name I-entity_name I-entity_name I-entity_name O B-playlist_owner B-playlist I-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'what will the weather be in bayside on sep  21  2034',
#   'slots': 'O O O O O O B-city O B-timeRange I-timeRange I-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'weather for four weeks from now in oregon',
#   'slots': 'O O B-timeRange I-timeRange I-timeRange I-timeRange O B-city',
#   'intent': 'GetWeather'},
#  {'utterance': 'rate this current essay five stars out of 6 total',
#   'slots': 'O O B-object_select B-object_type B-rating_value B-rating_unit O O B-best_rating O',
#   'intent': 'RateBook'},
#  {'utterance': 'what is the forecast for here fir storm conditions next week',
#   'slots': 'O O O O O B-current_location O B-condition_description O B-timeRange I-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'what films are playing in the neighbourhood',
#   'slots': 'O B-movie_type O O B-spatial_relation I-spatial_relation I-spatial_relation',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'book a table for josie  carissa and lindsay at a brasserie which serves trentino',
#   'slots': 'O O O O B-party_size_description I-party_size_description I-party_size_description I-party_size_description O O B-restaurant_type O O B-cuisine',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'what s the weather going to be like in fort point  san francisco tomorrow',
#   'slots': 'O O O O O O O O O B-geographic_poi I-geographic_poi I-geographic_poi I-geographic_poi B-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'book a restaurant for three on feb  18',
#   'slots': 'O O B-restaurant_type O B-party_size_number O B-timeRange I-timeRange',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'i want the turbonegro album to go on the playlist called genuine r&b',
#   'slots': 'O O O B-artist B-music_item O O O O O O B-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'play zvooq', 'slots': 'O B-service', 'intent': 'PlayMusic'},
#  {'utterance': 'give 4 out of 6 stars to the nightmare lands',
#   'slots': 'O B-rating_value O O B-best_rating B-rating_unit O B-object_name I-object_name I-object_name',
#   'intent': 'RateBook'},
#  {'utterance': 'can you give me the movie times',
#   'slots': 'O O O O O B-object_type I-object_type',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'how s the forecast looking for supper time in dresbach vanuatu',
#   'slots': 'O O O O O O B-timeRange O O B-city B-country',
#   'intent': 'GetWeather'},
#  {'utterance': 'can i get the marine 2 showtimes',
#   'slots': 'O O O B-movie_name I-movie_name I-movie_name O',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'play wendy james from the fifties',
#   'slots': 'O B-artist I-artist O O B-year',
#   'intent': 'PlayMusic'},
#  {'utterance': 'play some songs from the fourties by yoshiki fukuyama',
#   'slots': 'O O O O O B-year O B-artist I-artist',
#   'intent': 'PlayMusic'},
#  {'utterance': 'are there any animated movies playing in the neighborhood',
#   'slots': 'O O O B-movie_type I-movie_type O B-spatial_relation I-spatial_relation I-spatial_relation',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'where is my dearest enemy playing',
#   'slots': 'O O B-movie_name I-movie_name I-movie_name O',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'what s the weather going to be in parkers prairie  va at 07:08:02 am',
#   'slots': 'O O O O O O O O B-city I-city B-state O B-timeRange I-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'play a sound track from 1952',
#   'slots': 'O O B-music_item I-music_item O B-year',
#   'intent': 'PlayMusic'},
#  {'utterance': 'rate the current book 3 of 6',
#   'slots': 'O O B-object_select B-object_type B-rating_value O B-best_rating',
#   'intent': 'RateBook'},
#  {'utterance': 'find movie schedules at goodrich quality theaters',
#   'slots': 'O B-object_type I-object_type O B-location_name I-location_name I-location_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'add yma sumac to this is animal collective',
#   'slots': 'O B-artist I-artist O B-playlist I-playlist I-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'i giv the current novel a four',
#   'slots': 'O O O B-object_select B-object_type O B-rating_value',
#   'intent': 'RateBook'},
#  {'utterance': 'add an album to my list la mejor música dance 2017',
#   'slots': 'O O B-music_item O B-playlist_owner O B-playlist I-playlist I-playlist I-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'please book highly rated restaurant  with food truck tuscan for me and adela in hallam indiana',
#   'slots': 'O O B-sort I-sort B-restaurant_type O B-restaurant_type I-restaurant_type B-cuisine O B-party_size_description I-party_size_description I-party_size_description O B-city B-state',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'is it nice in pw',
#   'slots': 'O O O O B-state',
#   'intent': 'GetWeather'},
#  {'utterance': 'show me the schedule of films in the neighbourhood',
#   'slots': 'O O O B-object_type O B-movie_type B-spatial_relation I-spatial_relation I-spatial_relation',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'find innocent world',
#   'slots': 'O B-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'what is the weather forecast this week close-by my current position',
#   'slots': 'O O O O O B-timeRange I-timeRange B-spatial_relation O B-current_location I-current_location',
#   'intent': 'GetWeather'},
#  {'utterance': 'search for a painting of the wannadies',
#   'slots': 'O O O B-object_type O B-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'find the schedule for without witness twenty two hours from now',
#   'slots': 'O O B-object_type O B-movie_name I-movie_name B-timeRange I-timeRange I-timeRange I-timeRange I-timeRange',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'can you look up the molecular oncology saga',
#   'slots': 'O O O O O B-object_name I-object_name B-object_type',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'play netflix tunes from 2003 on an album',
#   'slots': 'O B-service O O B-year O O B-music_item',
#   'intent': 'PlayMusic'},
#  {'utterance': 'give the current album a score of five out of 6',
#   'slots': 'O O B-object_select B-object_type O O O B-rating_value O O B-best_rating',
#   'intent': 'RateBook'},
#  {'utterance': 'add the crabfish to my playlist called the sleep machine rainforest',
#   'slots': 'O B-entity_name I-entity_name O B-playlist_owner O O B-playlist I-playlist I-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'out of 6 stars i give the chronicle three and look forward to what s next',
#   'slots': 'O O B-best_rating B-rating_unit O O O B-object_part_of_series_type B-rating_value O O O O O O B-object_select',
#   'intent': 'RateBook'},
#  {'utterance': 'book me a reservation at a burger joint close-by choate on july 16th  2022',
#   'slots': 'O O O O O O B-served_dish B-restaurant_type B-spatial_relation B-city O B-timeRange I-timeRange I-timeRange',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'rate sandworms of dune three out of 6 stars',
#   'slots': 'O B-object_name I-object_name I-object_name B-rating_value O O B-best_rating B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'let me hear the live from the ghetto album by beau jocque',
#   'slots': 'O O O O B-album I-album I-album I-album B-music_item O B-artist I-artist',
#   'intent': 'PlayMusic'},
#  {'utterance': 'add singing in the trees to rena s lo mejor de radio 3 playlist',
#   'slots': 'O B-entity_name I-entity_name I-entity_name I-entity_name O B-playlist_owner I-playlist_owner B-playlist I-playlist I-playlist I-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'can you locate the novel  ismol family',
#   'slots': 'O O O O B-object_type B-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'can you find the tv show so what',
#   'slots': 'O O O O B-object_type I-object_type B-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'i want to give this textbook four out of 6',
#   'slots': 'O O O O B-object_select B-object_type B-rating_value O O B-best_rating',
#   'intent': 'RateBook'},
#  {'utterance': 'is it warmer in monson  u s  minor outlying islands',
#   'slots': 'O O B-condition_temperature O B-city B-country I-country I-country I-country I-country',
#   'intent': 'GetWeather'},
#  {'utterance': 'rate the series the quantity theory of insanity 1',
#   'slots': 'O O B-object_part_of_series_type B-object_name I-object_name I-object_name I-object_name I-object_name B-rating_value',
#   'intent': 'RateBook'},
#  {'utterance': 'add this artist to my pop punk s not dead',
#   'slots': 'O O B-music_item O B-playlist_owner B-playlist I-playlist I-playlist I-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'find 300: march to glory  a song',
#   'slots': 'O B-object_name I-object_name I-object_name I-object_name O B-object_type',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'what is the local movie schedule',
#   'slots': 'O O O O B-object_type I-object_type',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'i want to book a jewish restaurant in gambia',
#   'slots': 'O O O O O B-cuisine B-restaurant_type O B-country',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'add ian gillan to my rock party',
#   'slots': 'O B-artist I-artist O B-playlist_owner B-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'play a sixties soundtrack',
#   'slots': 'O O B-year B-music_item',
#   'intent': 'PlayMusic'},
#  {'utterance': 'i want do you want to build a snowman in my hip hop 2017 new school playlist',
#   'slots': 'O O B-entity_name I-entity_name I-entity_name I-entity_name I-entity_name I-entity_name I-entity_name O B-playlist_owner B-playlist I-playlist I-playlist I-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'will it be hotter today in holtwood',
#   'slots': 'O O O B-condition_temperature B-timeRange O B-city',
#   'intent': 'GetWeather'},
#  {'utterance': 'play symphony music from the fourties with google music',
#   'slots': 'O B-music_item O O O B-year O B-service I-service',
#   'intent': 'PlayMusic'},
#  {'utterance': 'is it windy in june park',
#   'slots': 'O O B-condition_description O B-city I-city',
#   'intent': 'GetWeather'},
#  {'utterance': 'can you get me seating for 5 people 1 minute from now in tuvalu',
#   'slots': 'O O O O O O B-party_size_number O B-timeRange I-timeRange I-timeRange I-timeRange O B-country',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'play larry graham sound track',
#   'slots': 'O B-artist I-artist B-music_item I-music_item',
#   'intent': 'PlayMusic'},
#  {'utterance': 'give this book a rating of four out of 6',
#   'slots': 'O B-object_select B-object_type O O O B-rating_value O O B-best_rating',
#   'intent': 'RateBook'},
#  {'utterance': 'what time can i expect films to start at the bow tie cinemas',
#   'slots': 'O O O O O B-movie_type O O O O B-location_name I-location_name I-location_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'i want to see everytime we touch which is a painting',
#   'slots': 'O O O O B-object_name I-object_name I-object_name O O O B-object_type',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'play anweshaa by the new first',
#   'slots': 'O B-artist O O B-sort O',
#   'intent': 'PlayMusic'},
#  {'utterance': 'can you pull up my name is brain brian',
#   'slots': 'O O O O B-object_name I-object_name I-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'i want to go see a troll in central park',
#   'slots': 'O O O O O B-movie_name I-movie_name I-movie_name I-movie_name I-movie_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'for the playlist running power add the name the best is yet to come',
#   'slots': 'O O O B-playlist I-playlist O O O B-entity_name I-entity_name I-entity_name I-entity_name I-entity_name I-entity_name',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'find the show titled the most charming and attractive',
#   'slots': 'O O B-object_type O B-object_name I-object_name I-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'what is the weather forecast for my current position',
#   'slots': 'O O O O O O O B-current_location I-current_location',
#   'intent': 'GetWeather'},
#  {'utterance': 'reserve a table for 3 people at the cubby bear   in comoros',
#   'slots': 'O O O O B-party_size_number O O B-restaurant_name I-restaurant_name I-restaurant_name O B-country',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'search for the show the caretaker',
#   'slots': 'O O O B-object_type B-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'add jalal zolfonun to my nature noise',
#   'slots': 'O B-artist I-artist O B-playlist_owner B-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'what is the forecast this evening for the calipuy national reservation',
#   'slots': 'O O O O O B-timeRange O O B-geographic_poi I-geographic_poi I-geographic_poi',
#   'intent': 'GetWeather'},
#  {'utterance': 'is it going to be foggy in box elder  rhode island',
#   'slots': 'O O O O O B-condition_description O B-city I-city B-state I-state',
#   'intent': 'GetWeather'},
#  {'utterance': 'play the last mile album',
#   'slots': 'O B-object_name I-object_name I-object_name B-object_type',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'play them by guy-manuel de homem-christo',
#   'slots': 'O B-music_item O B-artist I-artist I-artist',
#   'intent': 'PlayMusic'},
#  {'utterance': 'where can i find paranormal activity 3 playing near me 1 hour from now',
#   'slots': 'O O O O B-movie_name I-movie_name I-movie_name O O O B-timeRange I-timeRange I-timeRange I-timeRange',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'i want to hear box of rain by skeets mcdonald',
#   'slots': 'O O O O B-track I-track I-track O B-artist I-artist',
#   'intent': 'PlayMusic'},
#  {'utterance': 'book a restaurant in one minute for five people in canal fulton',
#   'slots': 'O O B-restaurant_type B-timeRange I-timeRange I-timeRange O B-party_size_number O O B-city I-city',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'add this tune by hart wand on this is wagner',
#   'slots': 'O O B-music_item O B-artist I-artist O B-playlist I-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'play slow rock on lastfm',
#   'slots': 'O B-genre I-genre O B-service',
#   'intent': 'PlayMusic'},
#  {'utterance': 'what will the weather be on april 9  2037 in new brunswick botanical garden',
#   'slots': 'O O O O O O B-timeRange I-timeRange I-timeRange O B-geographic_poi I-geographic_poi I-geographic_poi I-geographic_poi',
#   'intent': 'GetWeather'},
#  {'utterance': 'what s on the movie schedules at amco entertainment',
#   'slots': 'O O O O B-object_type I-object_type O B-location_name I-location_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'weather for knierim kansas in twelve weeks and a half from now',
#   'slots': 'O O B-city B-state O B-timeRange I-timeRange I-timeRange I-timeRange I-timeRange I-timeRange I-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'add the green book in my playlist mellowed out gaming',
#   'slots': 'O B-entity_name I-entity_name I-entity_name O B-playlist_owner O B-playlist I-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'add księga urodzaju to abigail s concentración',
#   'slots': 'O B-entity_name I-entity_name O B-playlist_owner I-playlist_owner B-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'play music from 2012 on google music',
#   'slots': 'O O O B-year O B-service I-service',
#   'intent': 'PlayMusic'},
#  {'utterance': 'can you put this song on the metal xplorer playlist',
#   'slots': 'O O O O B-music_item O O B-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'rate a battle of nerves three stars out of 6',
#   'slots': 'O B-object_name I-object_name I-object_name I-object_name B-rating_value B-rating_unit O O B-best_rating',
#   'intent': 'RateBook'},
#  {'utterance': 'rate the current series a zero',
#   'slots': 'O O B-object_select B-object_part_of_series_type O B-rating_value',
#   'intent': 'RateBook'},
#  {'utterance': 'the law of dreams gets a low rating of one',
#   'slots': 'B-object_name I-object_name I-object_name I-object_name O O O O O B-rating_value',
#   'intent': 'RateBook'},
#  {'utterance': 'please make reservations for nine at 3 am',
#   'slots': 'O O O O B-party_size_number O B-timeRange I-timeRange',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'put this song on my ntc high intensity training tracks playlist',
#   'slots': 'O O B-music_item O B-playlist_owner B-playlist I-playlist I-playlist I-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'play any chant from 1973',
#   'slots': 'O O B-music_item O B-year',
#   'intent': 'PlayMusic'},
#  {'utterance': 'play groove shark',
#   'slots': 'O B-service I-service',
#   'intent': 'PlayMusic'},
#  {'utterance': 'play anything jd natasha did in the thirties',
#   'slots': 'O O B-artist I-artist O O O B-year',
#   'intent': 'PlayMusic'},
#  {'utterance': 'rate steps two out of 6 points',
#   'slots': 'O B-object_name B-rating_value O O B-best_rating B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'book me a bar that s highly rated for georgia and i in burkina',
#   'slots': 'O O O B-restaurant_type O O B-sort I-sort O B-party_size_description I-party_size_description I-party_size_description O B-country',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'add tune to my playlist picnic in the park',
#   'slots': 'O B-music_item O B-playlist_owner O B-playlist I-playlist I-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'is cape mount nature conservation unit has storm weather',
#   'slots': 'O B-geographic_poi I-geographic_poi I-geographic_poi I-geographic_poi I-geographic_poi O B-condition_description O',
#   'intent': 'GetWeather'},
#  {'utterance': 'is it colder in paraguay this morning',
#   'slots': 'O O B-condition_temperature O B-country O B-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'find cluster computing  a game',
#   'slots': 'O B-object_name I-object_name O B-object_type',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'book for sherry and concepcion in nunam iqua at the best restaurant',
#   'slots': 'O O B-party_size_description I-party_size_description I-party_size_description O B-city I-city O O B-sort B-restaurant_type',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'can you play a 1967 soundtrack on slacker',
#   'slots': 'O O O O B-year B-music_item O B-service',
#   'intent': 'PlayMusic'},
#  {'utterance': 'find movie times for close by films',
#   'slots': 'O B-object_type I-object_type O B-spatial_relation I-spatial_relation B-movie_type',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'tell me what films are playing at plitt theatres',
#   'slots': 'O O O B-movie_type O O O B-location_name I-location_name',
#   'intent': 'SearchScreeningEvent'},
# ...
#   'intent': 'PlayMusic'},
#  {'utterance': 'i want to see the local movie times',
#   'slots': 'O O O O O O B-object_type I-object_type',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'add this album to rock en español',
#   'slots': 'O O B-music_item O B-playlist I-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'get me a picture about sardonic wrath',
#   'slots': 'O O O B-object_type O B-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'book a joint for feb  the seventh in oklahoma within walking distance for six that is highly rated',
#   'slots': 'O O B-restaurant_type O B-timeRange I-timeRange I-timeRange O B-state B-spatial_relation I-spatial_relation I-spatial_relation O B-party_size_number O O B-sort I-sort',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'i d like to see spyforce',
#   'slots': 'O O O O O B-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'i want to eat for two at a brasserie in gwynedd valley tn with pickled cucumber in one second',
#   'slots': 'O O O O O B-party_size_number O O B-restaurant_type O B-city I-city B-state O B-served_dish I-served_dish B-timeRange I-timeRange I-timeRange',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'book osteria restaurant for 1 person in mi',
#   'slots': 'O B-restaurant_type I-restaurant_type O B-party_size_number O O B-state',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'what does for all the wrong reasons look like',
#   'slots': 'O O B-object_name I-object_name I-object_name I-object_name I-object_name O O',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'i want to book a reservation within the same area of amelia court house for 4',
#   'slots': 'O O O O O O B-spatial_relation I-spatial_relation I-spatial_relation I-spatial_relation O B-city I-city I-city O B-party_size_number',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'is the forecast chillier in 1 hour in mali',
#   'slots': 'O O O B-condition_temperature B-timeRange I-timeRange I-timeRange O B-country',
#   'intent': 'GetWeather'},
#  {'utterance': 'where is the chief cook playing',
#   'slots': 'O O B-movie_name I-movie_name I-movie_name O',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'book a table for me and my crew scheduled for 10:47:15 pm in il',
#   'slots': 'O O O O B-party_size_description I-party_size_description I-party_size_description I-party_size_description O O B-timeRange I-timeRange O B-state',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'find the schedule for ghost world',
#   'slots': 'O O B-object_type O B-movie_name I-movie_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'find the nearest movie house with pirates of the 20th century',
#   'slots': 'O O B-spatial_relation B-object_location_type I-object_location_type O B-movie_name I-movie_name I-movie_name I-movie_name I-movie_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'what is the weather prediction for acworth  north korea in six years',
#   'slots': 'O O O O O O B-city B-country I-country B-timeRange I-timeRange I-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'play remains of the day',
#   'slots': 'O B-object_name I-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'i want to put this song in my new boots playlist',
#   'slots': 'O O O O O B-music_item O B-playlist_owner B-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'add bert mccracken tune lo que suena new york playlist',
#   'slots': 'O B-artist I-artist B-music_item B-playlist I-playlist I-playlist I-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'give the current essay 5 / 6 stars',
#   'slots': 'O O B-object_select B-object_type B-rating_value O B-best_rating B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'book a taverna for a party of 10',
#   'slots': 'O O B-restaurant_type O O O O B-party_size_number',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'add song to daily lift playlist',
#   'slots': 'O B-music_item O B-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'what time is the eddy duchin story playing',
#   'slots': 'O O O B-movie_name I-movie_name I-movie_name I-movie_name O',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'book me a reservation at an oyster bar that serves crab cake for two people',
#   'slots': 'O O O O O O B-restaurant_type I-restaurant_type O O B-served_dish I-served_dish O B-party_size_number O',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'add josephine wiggs to my kickass metal playlist',
#   'slots': 'O B-artist I-artist O B-playlist_owner B-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'book a spot for ten in morris ranch sd on nov  the twenty-second  2023',
#   'slots': 'O O O O B-party_size_number O B-city I-city B-state O B-timeRange I-timeRange I-timeRange I-timeRange',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'what s the weather forrecast here in five seconds',
#   'slots': 'O O O O O B-current_location B-timeRange I-timeRange I-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'add xiang xiang album to my madden nfl 16',
#   'slots': 'O B-artist I-artist B-music_item O B-playlist_owner B-playlist I-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'play something by louis nelson delisle',
#   'slots': 'O O O B-artist I-artist I-artist',
#   'intent': 'PlayMusic'},
#  {'utterance': 'i give this book five stars out of 6',
#   'slots': 'O O B-object_select B-object_type B-rating_value B-rating_unit O O B-best_rating',
#   'intent': 'RateBook'},
#  {'utterance': 'show me the picture written in the stars',
#   'slots': 'O O O B-object_type B-object_name I-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'i want to listen to keep the faith',
#   'slots': 'O O O O O B-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'play a melody by avery storm',
#   'slots': 'O O B-music_item O B-artist I-artist',
#   'intent': 'PlayMusic'},
#  {'utterance': 'find the tv series shaun the sheep',
#   'slots': 'O O B-object_type I-object_type B-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'will it be snowy in crouch  french polynesia',
#   'slots': 'O O O B-condition_description O B-city B-country I-country',
#   'intent': 'GetWeather'},
#  {'utterance': 'play music from 2014',
#   'slots': 'O O O B-year',
#   'intent': 'PlayMusic'},
#  {'utterance': 'the book as sure as the dawn gets a two out of 6 rating',
#   'slots': 'O B-object_type B-object_name I-object_name I-object_name I-object_name I-object_name O O B-rating_value O O B-best_rating O',
#   'intent': 'RateBook'},
#  {'utterance': 'can i get the showtimes for films close by',
#   'slots': 'O O O O O O B-movie_type B-spatial_relation I-spatial_relation',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'will it be cloudy not far  from allenton',
#   'slots': 'O O O B-condition_description B-spatial_relation I-spatial_relation O B-city',
#   'intent': 'GetWeather'},
#  {'utterance': 'christie  concepcion and i want to eat trattoria at a brasserie in johnston now',
#   'slots': 'B-party_size_description I-party_size_description I-party_size_description I-party_size_description O O O B-cuisine O O B-restaurant_type O B-city B-timeRange',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'i d like the weather forecast in gang mills four years from now',
#   'slots': 'O O O O O O O B-city I-city B-timeRange I-timeRange I-timeRange I-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'is the mystery of betty bonn playing at twelve a m  at the nearest movie house',
#   'slots': 'O B-movie_name I-movie_name I-movie_name I-movie_name I-movie_name O O B-timeRange I-timeRange I-timeRange O O B-spatial_relation B-object_location_type I-object_location_type',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'book a brasserie restaurant in enfield  north dakota for rosie and i that has tarte tatin',
#   'slots': 'O O B-restaurant_type I-restaurant_type O B-city B-state I-state O B-party_size_description I-party_size_description I-party_size_description O O B-served_dish I-served_dish',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'play some movement music by perez prado on iheart',
#   'slots': 'O O B-music_item O O B-artist I-artist O B-service',
#   'intent': 'PlayMusic'},
#  {'utterance': 'play a symphony from the thirties',
#   'slots': 'O O B-music_item O O B-year',
#   'intent': 'PlayMusic'},
#  {'utterance': 'book a diner place or me and my best friend on holy saturday  capital of united arab emirates  where they serve pepperoni dishes',
#   'slots': 'O O B-restaurant_type O O B-party_size_description I-party_size_description I-party_size_description I-party_size_description I-party_size_description O B-timeRange I-timeRange O O B-country I-country I-country O O O B-served_dish O',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'is convoy busters playing',
#   'slots': 'O B-movie_name I-movie_name O',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'book a table for 10 at the dome  edinburgh',
#   'slots': 'O O O O B-party_size_number O B-restaurant_name I-restaurant_name I-restaurant_name',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'can i put indocumentado onto my folk music at the gaslight café playlist',
#   'slots': 'O O O B-entity_name O B-playlist_owner B-playlist I-playlist I-playlist I-playlist I-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'please book me a table for 1 person at a brasserie',
#   'slots': 'O O O O O O B-party_size_number O O O B-restaurant_type',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'add curious corn to wild & free workout',
#   'slots': 'O B-entity_name I-entity_name O B-playlist I-playlist I-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'book me a restaurant in ware shoals that serves russian tea cake',
#   'slots': 'O O O B-restaurant_type O B-city I-city O O B-served_dish I-served_dish I-served_dish',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'show me the new showings for animated movies in the neighborhood',
#   'slots': 'O O O O O O B-movie_type I-movie_type B-spatial_relation I-spatial_relation I-spatial_relation',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'add artist to laundry',
#   'slots': 'O B-music_item O B-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'please rate the current textbook 2 stars',
#   'slots': 'O O O B-object_select B-object_type B-rating_value B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'please search the songs for the deaf video game',
#   'slots': 'O O O B-object_name I-object_name I-object_name I-object_name B-object_type I-object_type',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'wish to see the photograph with the name live: right here',
#   'slots': 'O O O O B-object_type O O O B-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'book a spot at leopold cafe in bhutan',
#   'slots': 'O O O O B-restaurant_name I-restaurant_name O B-country',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'what movies are playing at the closest cinema',
#   'slots': 'O B-movie_type O O O O B-spatial_relation B-object_location_type',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'rate the current novel two points',
#   'slots': 'O O B-object_select B-object_type B-rating_value B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'book me and my nieces a reservation for a seafood restaurant in cle elum  ne on ascension day',
#   'slots': 'O B-party_size_description I-party_size_description I-party_size_description I-party_size_description O O O O B-served_dish B-restaurant_type O B-city I-city B-state O B-timeRange I-timeRange',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'find sailing the seas of cheese',
#   'slots': 'O B-object_name I-object_name I-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'tell me the movie schedules',
#   'slots': 'O O O B-object_type I-object_type',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'look up the game called the long morrow',
#   'slots': 'O O O B-object_type O B-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'add this track to the classical music for smart kids playlist',
#   'slots': 'O O B-music_item O O B-playlist I-playlist I-playlist I-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'can you get me seating for a party of 5',
#   'slots': 'O O O O O O O O O B-party_size_number',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'please play something catchy on youtube',
#   'slots': 'O O O B-playlist O B-service',
#   'intent': 'PlayMusic'},
#  {'utterance': 'give me the showtimes for sign of the anchor',
#   'slots': 'O O O O O B-movie_name I-movie_name I-movie_name I-movie_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'add this song to my playlist named britpop  etc',
#   'slots': 'O O B-music_item O B-playlist_owner O O B-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'what is the weather supposed to be like in new jersey three months from now',
#   'slots': 'O O O O O O O O O B-state I-state B-timeRange I-timeRange I-timeRange I-timeRange',
#   'intent': 'GetWeather'},
#  {'utterance': 'play water under the bridge by hariprasad chaurasia',
#   'slots': 'O B-track I-track I-track I-track O B-artist I-artist',
#   'intent': 'PlayMusic'},
#  {'utterance': 'play some instrumental music on the service lastfm',
#   'slots': 'O O B-genre O O O O B-service',
#   'intent': 'PlayMusic'},
#  {'utterance': 'add blue feather to the nature noise playlist',
#   'slots': 'O B-entity_name I-entity_name O O B-playlist I-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'what movie is at loews cineplex entertainment',
#   'slots': 'O B-movie_type O O B-location_name I-location_name I-location_name',
#   'intent': 'SearchScreeningEvent'},
#  {'utterance': 'find as live as it gets',
#   'slots': 'O B-object_name I-object_name I-object_name I-object_name I-object_name',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'hocus bogus gets a 2 of 6',
#   'slots': 'B-object_name I-object_name O O B-rating_value O B-best_rating',
#   'intent': 'RateBook'},
#  {'utterance': 'book a table at top pot doughnuts in greensburg  american samoa',
#   'slots': 'O O O O B-restaurant_name I-restaurant_name I-restaurant_name O B-city B-state I-state',
#   'intent': 'BookRestaurant'},
#  {'utterance': 'get me the elvis’ christmas album tv show',
#   'slots': 'O O O B-object_name I-object_name I-object_name B-object_type I-object_type',
#   'intent': 'SearchCreativeWork'},
#  {'utterance': 'play alfredo zitarrosa on spotify',
#   'slots': 'O B-artist I-artist O B-service',
#   'intent': 'PlayMusic'},
#  {'utterance': 'please add this song to indiespain list',
#   'slots': 'O O O B-music_item O B-playlist O',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'play ik hou van jou by elena temnikova',
#   'slots': 'O B-track I-track I-track I-track O B-artist I-artist',
#   'intent': 'PlayMusic'},
#  {'utterance': 'rate know ye not agincourt 2 out of 6 stars',
#   'slots': 'O B-object_name I-object_name I-object_name I-object_name B-rating_value O O B-best_rating B-rating_unit',
#   'intent': 'RateBook'},
#  {'utterance': 'play paul ortiz music from 1990',
#   'slots': 'O B-artist I-artist O O B-year',
#   'intent': 'PlayMusic'},
#  {'utterance': 'whats  the weather in fernando new jersey',
#   'slots': 'O O O O B-city B-state I-state',
#   'intent': 'GetWeather'},
#  {'utterance': 'add the muppet show 2 to my party through the decades',
#   'slots': 'O B-entity_name I-entity_name I-entity_name I-entity_name O B-playlist_owner B-playlist I-playlist I-playlist I-playlist',
#   'intent': 'AddToPlaylist'},
#  {'utterance': 'play pandora christian gangsta rap',
#   'slots': 'O B-service B-genre I-genre I-genre',
#   'intent': 'PlayMusic'},
#  {'utterance': 'play isham jones',
#   'slots': 'O B-artist I-artist',
#   'intent': 'PlayMusic'},
#  ...]

# %%
train_list = []
val_list = []
# Load data into respective dicts
for data in data_dict:
    train_list.append([data['utterance'],data['intent']])
    
for vdata in vdata_dict:
    val_list.append([vdata['utterance'],vdata['intent']])

# %%
# Converting to Dataframe for sorting/filtering
train_df = pd.DataFrame(train_list, columns =['text', 'intent'])
val_df = pd.DataFrame(val_list, columns =['text', 'intent'])

# %%
train_df.head(10)
# Out:
#                                                 text              intent
# 0                         will it be rainy in tenino          GetWeather
# 1  add steve albini album to my psychedelic rock ...       AddToPlaylist
# 2  book a table for 3 at one of the restaurants i...      BookRestaurant
# 3            what s the weather forecast for belknap          GetWeather
# 4               play fereydoun farrokhzad best track           PlayMusic
# 5               put kan mikami on pre-party r&b jams       AddToPlaylist
# 6  look for the chu chu and the philly flash picture  SearchCreativeWork
# 7                  play the god that failed on vimeo           PlayMusic
# 8       play a soundtrack by mike hindert on spotify           PlayMusic
# 9      want to watch the tv show treeful of starling  SearchCreativeWork

# %%
val_df.head(10)
# Out:
#                                                 text                intent
# 0          i d like to see the show onion sportsdome    SearchCreativeWork
# 1                      give the current book 4 stars              RateBook
# 2     reserve a table for 8 in neighboring hitchland        BookRestaurant
# 3          show creative video game the boat is full    SearchCreativeWork
# 4  put once bitten twice bitten into the pulse of...         AddToPlaylist
# 5           what time is the ladies diplomat playing  SearchScreeningEvent
# 6  i want to book a bistro that serves pasta sala...        BookRestaurant
# 7                              play a song from 2003             PlayMusic
# 8                       rate current novel two stars              RateBook
# 9   add the field album to my romantic evening album         AddToPlaylist

# %%
trainfeatures=train_df.copy()
trainlabels=trainfeatures.pop('intent')

# %%
trainfeatures=trainfeatures.values

# %%
from sklearn.preprocessing import LabelBinarizer
binarizer=LabelBinarizer()
trainlabels=binarizer.fit_transform(trainlabels.values)

# %%
# testfeatures=testdf.copy()
# testlabels=testfeatures.pop("intent")
validfeatures=val_df.copy()
validlabels=validfeatures.pop("intent")

# testfeatures=testfeatures.values
validfeatures=validfeatures.values

# testlabels=binarizer.transform(testlabels.values)
validlabels=binarizer.transform(validlabels.values)

# %%
bert_model_name = 'bert_en_uncased_L-12_H-768_A-12'

# %%
map_name_to_handle = {
    'bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/3',
    'bert_en_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_cased_L-12_H-768_A-12/3',
    'bert_multi_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_multi_cased_L-12_H-768_A-12/3',
    'small_bert/bert_en_uncased_L-2_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-2_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-2_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-2_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-4_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-4_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-4_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-4_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-6_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-6_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-6_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-6_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-8_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-8_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-8_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-8_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-10_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-10_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-10_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-10_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-12_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-12_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-12_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-768_A-12/1',
    'albert_en_base':
        'https://tfhub.dev/tensorflow/albert_en_base/2',
    'electra_small':
        'https://tfhub.dev/google/electra_small/2',
    'electra_base':
        'https://tfhub.dev/google/electra_base/2',
    'experts_pubmed':
        'https://tfhub.dev/google/experts/bert/pubmed/2',
    'experts_wiki_books':
        'https://tfhub.dev/google/experts/bert/wiki_books/2',
    'talking-heads_base':
        'https://tfhub.dev/tensorflow/talkheads_ggelu_bert_en_base/1',
}

map_model_to_preprocess = {
    'bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'bert_en_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_cased_preprocess/2',
    'small_bert/bert_en_uncased_L-2_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-2_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-2_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-2_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-4_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-4_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-4_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-4_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-6_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-6_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-6_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-6_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-8_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-8_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-8_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-8_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-10_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-10_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-10_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-10_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-12_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-12_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-12_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'small_bert/bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'bert_multi_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_multi_cased_preprocess/2',
    'albert_en_base':
        'https://tfhub.dev/tensorflow/albert_en_preprocess/2',
    'electra_small':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'electra_base':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'experts_pubmed':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'experts_wiki_books':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
    'talking-heads_base':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/2',
}

tfhub_handle_encoder = map_name_to_handle[bert_model_name]
tfhub_handle_preprocess = map_model_to_preprocess[bert_model_name]

print(f'BERT model selected           : {tfhub_handle_encoder}')
print(f'Preprocess model auto-selected: {tfhub_handle_preprocess}')

# %%
bert_preprocess_model = hub.KerasLayer(tfhub_handle_preprocess)

# %%
text_test = trainfeatures[0]
text_preprocessed = bert_preprocess_model(text_test)

print(f'Keys       : {list(text_preprocessed.keys())}')
print(f'Shape      : {text_preprocessed["input_word_ids"].shape}')
print(f'Word Ids   : {text_preprocessed["input_word_ids"][0, :12]}')
print(f'Input Mask : {text_preprocessed["input_mask"][0, :12]}')
print(f'Type Ids   : {text_preprocessed["input_type_ids"][0, :12]}')

# %%
bert_model = hub.KerasLayer(tfhub_handle_encoder)

# %%
bert_results = bert_model(text_preprocessed)

# %%
def build_classifier_model():
    text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
    preprocessing_layer = hub.KerasLayer(tfhub_handle_preprocess, name='preprocessing')
    encoder_inputs = preprocessing_layer(text_input)
    encoder = hub.KerasLayer(tfhub_handle_encoder, trainable=True, name='BERT_encoder')
    outputs = encoder(encoder_inputs)
    net = outputs['pooled_output']
    net = tf.keras.layers.Dropout(0.1)(net)
    net = tf.keras.layers.Dense(7, activation=None, name='classifier')(net)
    return tf.keras.Model(text_input, net)

# %%
classifier_model = build_classifier_model()
bert_raw_result = classifier_model(tf.constant(trainfeatures[0]))
print(tf.keras.activations.softmax(bert_raw_result))

# %%
classifier_model.summary()

# %%
loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
metrics = tf.metrics.CategoricalAccuracy()

# %%
epochs=5
optimizer=tf.keras.optimizers.Adam(1e-5)
classifier_model.compile(optimizer=optimizer,
                         loss=loss,
                         metrics=metrics)

# %%
print(f'Training model with {tfhub_handle_encoder}')
history = classifier_model.fit(x=trainfeatures,y=trainlabels,
                               validation_data=(validfeatures,validlabels),
                               batch_size=32,
                               epochs=epochs)

# %%
scores = classifier_model.evaluate(validfeatures,validlabels, verbose=0)
print("Accuracy: " , (scores[1] * 100))

# %% [markdown]
# # # Submission

# %%
df_sub = pd.read_csv('/kaggle/input/hackathon-online-nlu-intent-classification/test.csv')
df_sub.head()

# %%
X_sub = df_sub[['utterance']].to_numpy().reshape(-1)
X_sub

# %%
binarizer.classes_

# %%
test_pre = classifier_model.predict(X_sub)
pred_class = np.argmax(test_pre, axis=1)
pred_class

# %%
prediction = []
for i in pred_class:
    if i == 0:
        prediction.append("AddToPlaylist")
    elif i == 1:
        prediction.append("BookRestaurant")
    elif i == 2:
        prediction.append("GetWeather")
    elif i == 3:
        prediction.append("PlayMusic")
    elif i == 4:
        prediction.append("RateBook")
    elif i == 5:
        prediction.append("SearchCreativeWork")
    elif i == 6:
        prediction.append("SearchScreeningEvent") 
              
# for i in range(280):
#     test_list = ["AddToPlaylist", "BookRestaurant", "GetWeather", "PlayMusic", "RateBook", "SearchCreativeWork", "SearchScreeningEvent"]  
#     prediction.append(random.choice(test_list))

# %%
submit = pd.DataFrame({'id':df_sub["id"],
                      'intent':prediction})

submit.to_csv('submission5.csv', index=False)

# %%
model = classifier_model
model.save('modelIntent.h5')
